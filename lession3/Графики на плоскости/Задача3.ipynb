# %% [markdown]
# ### ЗАДАНИЕ
# Напишите код, который будет переводить полярные координаты в декартовы.<br>
# Напишите код, который будет рисовать график окружности в полярных координатах.<br>
# Напишите код, который будет рисовать график отрезка прямой линии в полярных координатах.<br>

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0, 5 ,21)
y = (x-2)**2+1
plt.plot(x, y)

# %%
s = np.pi/2
x1 = x*np.cos(s) + y*np.sin(s)
y1 = - x*np.sin(s) + y*np.cos(s)
plt.plot(x1,y1)

# %% [markdown]
# ### ЗАДАНИЕ
# 1.Напишите код, который будет переводить полярные координаты в декартовы.

# %% [markdown]
# Формулы перевода полярной системы координат:<br>
# x = R*cos(alpha)<br>
# y = R*sin(alpha)<br>
# R = scrt(x^2+y^2)

# %%
alpha = np.pi/3
R = 15
x = R * np.cos(alpha)
y = R * np.sin(alpha)
Rt = pow(x**2 + y**2, 0.5)
print(f'Координаты равны ({x, y})')
print(f'Проверка Rt={Rt}')
# Out:
# Координаты равны ((7.500000000000002, 12.990381056766578))
# Проверка Rt=15.0

# %% [markdown]
# Преобразование выполнено верно

# %% [markdown]
# ### ЗАДАНИЕ
# 2.Напишите код, который будет рисовать график окружности в полярных координатах.

# %% [markdown]
# Исходя из формулы полярной системы координат, окружность можно получить когда функция не зависит от alpha.<br>
# Т.е. для каждого x будет равное значение

# %%
x = np.linspace(-np.pi,np.pi,100)

y = [3]*100
plt.polar(x,y)

# %% [markdown]
# ### ЗАДАНИЕ
# 3. Напишите код, который будет рисовать график отрезка прямой линии в полярных координатах.

# %% [markdown]
# Исходя из формулы полярной системы координат, окружность можно получить когда функция не зависит от R.
# Т.е. равное значение x при различном y

# %%
x = [0]*100

y = np.linspace(0,np.pi,100)
plt.polar(x,y)
